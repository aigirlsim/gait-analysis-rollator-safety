# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import (
    f1_score,
    roc_auc_score,
    matthews_corrcoef,
    classification_report,
    confusion_matrix,
)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns


# Load and prepare data
def load_data(file_path):
    df = pd.read_csv(file_path)
    X = df.drop(columns=["label"])
    y = df["label"].astype(int)
    return X, y


# Preprocessing pipeline
def preprocess_data(X, y):
    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, stratify=y, random_state=42
    )

    # Standardization
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    return X_train, X_test, y_train, y_test, scaler


# Autoencoder architecture
def build_autoencoder(input_dim):
    input_layer = Input(shape=(input_dim,))

    # Encoder
    encoded = Dense(64, activation="relu")(input_layer)
    encoded = Dense(32, activation="relu")(encoded)
    encoded = Dense(16, activation="relu")(encoded)
    encoded = Dense(8, activation="relu")(encoded)  # Bottleneck

    # Decoder
    decoded = Dense(16, activation="relu")(encoded)
    decoded = Dense(32, activation="relu")(decoded)
    decoded = Dense(64, activation="relu")(decoded)
    decoded = Dense(input_dim, activation="linear")(decoded)

    autoencoder = Model(input_layer, decoded)
    encoder = Model(input_layer, encoded)

    return autoencoder, encoder


# Main pipeline
def main():
    # Load data
    X, y = load_data(
        "/content/drive/MyDrive/new gait data/Final Data/gait_features_engineered_v2.csv"
    )

    # Preprocess
    X_train, X_test, y_train, y_test, scaler = preprocess_data(X, y)
    input_dim = X_train.shape[1]

    # Build and train autoencoder
    autoencoder, encoder = build_autoencoder(input_dim)
    autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss="mse")
    history = autoencoder.fit(
        X_train, X_train, epochs=150, batch_size=32, validation_split=0.2, verbose=1
    )

    # Visualize training progress
    plt.plot(history.history["loss"], label="Train Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.title("Autoencoder Training Progress")
    plt.ylabel("MSE Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

    # Encode features
    X_train_enc = encoder.predict(X_train)
    X_test_enc = encoder.predict(X_test)

    # Train Gradient Boosting
    gb = GradientBoostingClassifier(
        n_estimators=200, learning_rate=0.05, max_depth=3, random_state=42
    )
    gb.fit(X_train_enc, y_train)

    # Evaluate
    y_pred = gb.predict(X_test_enc)
    y_proba = gb.predict_proba(X_test_enc)[:, 1]

    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print(f"F1 Score: {f1_score(y_test, y_pred):.4f}")
    print(f"AUC-ROC: {roc_auc_score(y_test, y_proba):.4f}")
    print(f"MCC (Matthews): {matthews_corrcoef(y_test, y_pred):.4f}")

    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # Composite Safety Score (CSS)
    X_test_recon = autoencoder.predict(X_test)
    recon_error = np.mean(np.square(X_test - X_test_recon), axis=1)

    # Normalize scores
    recon_norm = (recon_error - np.min(recon_error)) / (
        np.max(recon_error) - np.min(recon_error)
    )
    proba_norm = (y_proba - np.min(y_proba)) / (np.max(y_proba) - np.min(y_proba))

    # Weighted CSS (adjust weights based on domain requirements)
    CSS = 0.6 * proba_norm + 0.4 * recon_norm

    # Safety thresholds (validate with domain experts)
    safety_labels = np.where(
        CSS < 0.4, "Safe", np.where(CSS < 0.7, "Warning", "Unsafe")
    )

    # Create results dataframe
    results = pd.DataFrame(
        {
            "True_Label": y_test,
            "Predicted_Label": y_pred,
            "Predicted_Probability": y_proba,
            "Reconstruction_Error": recon_error,
            "CSS": CSS,
            "Safety_Level": safety_labels,
        }
    )

    # Visualize safety distribution
    plt.figure(figsize=(10, 6))
    sns.histplot(data=results, x="CSS", hue="Safety_Level", bins=20, palette="viridis")
    plt.title("Composite Safety Score Distribution")
    plt.xlabel("CSS Score")
    plt.ylabel("Count")
    plt.show()

    # Analyze reconstruction errors
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=recon_error, y=y_proba, hue=y_test, palette="coolwarm")
    plt.title("Reconstruction Error vs. Predicted Probability")
    plt.xlabel("Reconstruction Error")
    plt.ylabel("Abnormality Probability")
    plt.show()

    return results


if __name__ == "__main__":
    results = main()
    print("\nFinal Results Preview:")
    print(results.head())
# Out:
# Epoch 1/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - loss: 1.0156 - val_loss: 1.0258
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.0038 - val_loss: 1.0279
# Epoch 3/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.9960 - val_loss: 1.0302
# Epoch 4/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.9897 - val_loss: 1.0325
# Epoch 5/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.9864 - val_loss: 1.0350
# Epoch 6/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.9715 - val_loss: 1.0354
# Epoch 7/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.9712 - val_loss: 1.0328
# Epoch 8/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.9717 - val_loss: 1.0298
# Epoch 9/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.9649 - val_loss: 1.0264
# Epoch 10/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.9594 - val_loss: 1.0228
# Epoch 11/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.9562 - val_loss: 1.0194
# Epoch 12/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.9514 - val_loss: 1.0164
# Epoch 13/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.9361 - val_loss: 1.0140
# Epoch 14/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.9347 - val_loss: 1.0123
# Epoch 15/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.9217 - val_loss: 1.0113
# Epoch 16/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.9194 - val_loss: 1.0110
# Epoch 17/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.8880 - val_loss: 1.0101
# Epoch 18/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.8933 - val_loss: 1.0089
# Epoch 19/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.8869 - val_loss: 1.0077
# Epoch 20/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.8696 - val_loss: 1.0049
# Epoch 21/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.8626 - val_loss: 1.0018
# Epoch 22/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.8503 - val_loss: 0.9994
# Epoch 23/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.8387 - val_loss: 0.9974
# Epoch 24/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.8024 - val_loss: 0.9946
# Epoch 25/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.8088 - val_loss: 0.9913
# Epoch 26/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.7941 - val_loss: 0.9870
# Epoch 27/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.7798 - val_loss: 0.9795
# Epoch 28/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.7631 - val_loss: 0.9707
# Epoch 29/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.7513 - val_loss: 0.9617
# Epoch 30/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.7366 - val_loss: 0.9486
# Epoch 31/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.7376 - val_loss: 0.9337
# Epoch 32/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.7108 - val_loss: 0.9251
# Epoch 33/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.7127 - val_loss: 0.9214
# Epoch 34/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.7023 - val_loss: 0.9191
# Epoch 35/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6935 - val_loss: 0.9191
# Epoch 36/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.6793 - val_loss: 0.9170
# Epoch 37/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6705 - val_loss: 0.9103
# Epoch 38/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6671 - val_loss: 0.9058
# Epoch 39/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6627 - val_loss: 0.9051
# Epoch 40/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6595 - val_loss: 0.9025
# Epoch 41/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.6466 - val_loss: 0.8986
# Epoch 42/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6460 - val_loss: 0.8977
# Epoch 43/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.6286 - val_loss: 0.8947
# Epoch 44/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.6304 - val_loss: 0.8902
# Epoch 45/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6203 - val_loss: 0.8868
# Epoch 46/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6082 - val_loss: 0.8821
# Epoch 47/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6078 - val_loss: 0.8759
# Epoch 48/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5934 - val_loss: 0.8682
# Epoch 49/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.5910 - val_loss: 0.8610
# Epoch 50/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.5881 - val_loss: 0.8558
# Epoch 51/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.5816 - val_loss: 0.8531
# Epoch 52/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.5788 - val_loss: 0.8530
# Epoch 53/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5694 - val_loss: 0.8548
# Epoch 54/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.5651 - val_loss: 0.8576
# Epoch 55/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5610 - val_loss: 0.8619
# Epoch 56/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.5554 - val_loss: 0.8655
# Epoch 57/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5500 - val_loss: 0.8689
# Epoch 58/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5471 - val_loss: 0.8719
# Epoch 59/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5439 - val_loss: 0.8745
# Epoch 60/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.5360 - val_loss: 0.8788
# Epoch 61/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.5324 - val_loss: 0.8846
# Epoch 62/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5253 - val_loss: 0.8784
# Epoch 63/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.5295 - val_loss: 0.8599
# Epoch 64/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.5155 - val_loss: 0.8403
# Epoch 65/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.5162 - val_loss: 0.8245
# Epoch 66/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.5103 - val_loss: 0.8203
# Epoch 67/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.5117 - val_loss: 0.8257
# Epoch 68/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.5073 - val_loss: 0.8336
# Epoch 69/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.4948 - val_loss: 0.8420
# Epoch 70/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.4980 - val_loss: 0.8536
# Epoch 71/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.4964 - val_loss: 0.8670
# Epoch 72/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.4920 - val_loss: 0.8746
# Epoch 73/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.4903 - val_loss: 0.8735
# Epoch 74/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.4877 - val_loss: 0.8680
# Epoch 75/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.4880 - val_loss: 0.8647
# Epoch 76/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.4778 - val_loss: 0.8632
# Epoch 77/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.4827 - val_loss: 0.8612
# Epoch 78/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.4792 - val_loss: 0.8570
# Epoch 79/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.4706 - val_loss: 0.8514
# Epoch 80/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4712 - val_loss: 0.8434
# Epoch 81/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4683 - val_loss: 0.8346
# Epoch 82/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.4639 - val_loss: 0.8255
# Epoch 83/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.4463 - val_loss: 0.8228
# Epoch 84/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4496 - val_loss: 0.8284
# Epoch 85/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4419 - val_loss: 0.8387
# Epoch 86/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4484 - val_loss: 0.8500
# Epoch 87/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4446 - val_loss: 0.8576
# Epoch 88/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.4443 - val_loss: 0.8585
# Epoch 89/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4446 - val_loss: 0.8572
# Epoch 90/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4381 - val_loss: 0.8585
# Epoch 91/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.4342 - val_loss: 0.8577
# Epoch 92/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.4289 - val_loss: 0.8501
# Epoch 93/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4271 - val_loss: 0.8405
# Epoch 94/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4254 - val_loss: 0.8342
# Epoch 95/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.4244 - val_loss: 0.8314
# Epoch 96/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4227 - val_loss: 0.8305
# Epoch 97/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.4166 - val_loss: 0.8315
# Epoch 98/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.4152 - val_loss: 0.8337
# Epoch 99/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4006 - val_loss: 0.8358
# Epoch 100/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4048 - val_loss: 0.8389
# Epoch 101/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3989 - val_loss: 0.8438
# Epoch 102/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.3983 - val_loss: 0.8500
# Epoch 103/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3988 - val_loss: 0.8551
# Epoch 104/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.3969 - val_loss: 0.8591
# Epoch 105/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3940 - val_loss: 0.8609
# Epoch 106/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.3943 - val_loss: 0.8620
# Epoch 107/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.3890 - val_loss: 0.8723
# Epoch 108/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3953 - val_loss: 0.8888
# Epoch 109/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3958 - val_loss: 0.8991
# Epoch 110/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3915 - val_loss: 0.8983
# Epoch 111/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3901 - val_loss: 0.8879
# Epoch 112/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3925 - val_loss: 0.8770
# Epoch 113/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3864 - val_loss: 0.8665
# Epoch 114/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3860 - val_loss: 0.8551
# Epoch 115/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3824 - val_loss: 0.8453
# Epoch 116/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.3737 - val_loss: 0.8378
# Epoch 117/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3711 - val_loss: 0.8307
# Epoch 118/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3699 - val_loss: 0.8227
# Epoch 119/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.3709 - val_loss: 0.8139
# Epoch 120/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3742 - val_loss: 0.8049
# Epoch 121/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3743 - val_loss: 0.7999
# Epoch 122/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3706 - val_loss: 0.7975
# Epoch 123/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3684 - val_loss: 0.7977
# Epoch 124/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.3568 - val_loss: 0.8104
# Epoch 125/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3567 - val_loss: 0.8374
# Epoch 126/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3480 - val_loss: 0.8678
# Epoch 127/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3498 - val_loss: 0.9002
# Epoch 128/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3523 - val_loss: 0.9238
# Epoch 129/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3600 - val_loss: 0.9251
# Epoch 130/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3608 - val_loss: 0.9038
# Epoch 131/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3621 - val_loss: 0.8838
# Epoch 132/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3512 - val_loss: 0.8741
# Epoch 133/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3518 - val_loss: 0.8749
# Epoch 134/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3427 - val_loss: 0.8782
# Epoch 135/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3396 - val_loss: 0.8721
# Epoch 136/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3350 - val_loss: 0.8609
# Epoch 137/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3302 - val_loss: 0.8475
# Epoch 138/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3242 - val_loss: 0.8355
# Epoch 139/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.3199 - val_loss: 0.8247
# Epoch 140/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3138 - val_loss: 0.8265
# Epoch 141/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.3210 - val_loss: 0.8445
# Epoch 142/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3258 - val_loss: 0.8651
# Epoch 143/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3338 - val_loss: 0.8730
# Epoch 144/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3353 - val_loss: 0.8601
# Epoch 145/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.3383 - val_loss: 0.8383
# Epoch 146/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.3337 - val_loss: 0.8176
# Epoch 147/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.3283 - val_loss: 0.8029
# Epoch 148/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.3302 - val_loss: 0.7966
# Epoch 149/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3259 - val_loss: 0.7941
# Epoch 150/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.3164 - val_loss: 0.7936
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# WARNING:tensorflow:5 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bedcc40bce0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         8
#            1       1.00      0.40      0.57        10
#
#     accuracy                           0.67        18
#    macro avg       0.79      0.70      0.65        18
# weighted avg       0.81      0.67      0.64        18
#
# F1 Score: 0.5714
# AUC-ROC: 0.7125
# MCC (Matthews): 0.4781
# WARNING:tensorflow:6 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bedcc4efba0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Final Results Preview:
#     True_Label  Predicted_Label  Predicted_Probability  Reconstruction_Error  \
# 27           1                1               0.916627              1.179829
# 17           1                0               0.008819              2.591717
# 33           0                0               0.000130              0.568847
# 57           0                0               0.036569              1.269550
# 55           1                0               0.079579              0.857766
#
#          CSS Safety_Level
# 27  0.721972       Unsafe
# 17  0.405224      Warning
# 33  0.071811         Safe
# 57  0.207401         Safe
# 55  0.166453         Safe

# %% [markdown]
# FINAL MODEL

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import (
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix,
)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns


# Load and prepare data
def load_data(file_path):
    df = pd.read_csv(file_path)
    X = df.drop(columns=["label"])
    y = df["label"].astype(int)
    return X, y


# Preprocessing pipeline
def preprocess_data(X, y):
    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.3, stratify=y, random_state=42
    )

    # Standardization
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    return X_train, X_test, y_train, y_test, scaler


# Autoencoder architecture
def build_autoencoder(input_dim):
    input_layer = Input(shape=(input_dim,))

    # Encoder
    encoded = Dense(64, activation="relu")(input_layer)
    encoded = Dense(32, activation="relu")(encoded)
    encoded = Dense(16, activation="relu")(encoded)
    encoded = Dense(8, activation="relu")(encoded)  # Bottleneck

    # Decoder
    decoded = Dense(16, activation="relu")(encoded)
    decoded = Dense(32, activation="relu")(decoded)
    decoded = Dense(64, activation="relu")(decoded)
    decoded = Dense(input_dim, activation="linear")(decoded)

    autoencoder = Model(input_layer, decoded)
    encoder = Model(input_layer, encoded)

    return autoencoder, encoder


# Main pipeline
def main():
    # Load data
    X, y = load_data(
        "/content/drive/MyDrive/new gait data/Final Data/gait_features_engineered_v2.csv"
    )

    # Preprocess
    X_train, X_test, y_train, y_test, scaler = preprocess_data(X, y)
    input_dim = X_train.shape[1]

    # Build and train autoencoder
    autoencoder, encoder = build_autoencoder(input_dim)
    autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss="mse")
    history = autoencoder.fit(
        X_train, X_train, epochs=150, batch_size=32, validation_split=0.2, verbose=1
    )

    # Visualize training progress
    plt.plot(history.history["loss"], label="Train Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.title("Autoencoder Training Progress")
    plt.ylabel("MSE Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

    # Encode features
    X_train_enc = encoder.predict(X_train)
    X_test_enc = encoder.predict(X_test)

    # Train Gradient Boosting
    gb = GradientBoostingClassifier(
        n_estimators=200, learning_rate=0.05, max_depth=3, random_state=42
    )
    gb.fit(X_train_enc, y_train)

    # Evaluate
    y_pred = gb.predict(X_test_enc)
    y_proba = gb.predict_proba(X_test_enc)[:, 1]

    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print(f"F1 Score: {f1_score(y_test, y_pred):.4f}")
    print(f"AUC-ROC: {roc_auc_score(y_test, y_proba):.4f}")

    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # Composite Safety Score (CSS)
    X_test_recon = autoencoder.predict(X_test)
    recon_error = np.mean(np.square(X_test - X_test_recon), axis=1)

    # Normalize scores
    recon_norm = (recon_error - np.min(recon_error)) / (
        np.max(recon_error) - np.min(recon_error)
    )
    proba_norm = (y_proba - np.min(y_proba)) / (np.max(y_proba) - np.min(y_proba))

    # Weighted CSS (adjust weights based on domain requirements)
    CSS = 0.6 * proba_norm + 0.4 * recon_norm

    # Safety thresholds (validate with domain experts)
    safety_labels = np.where(
        CSS < 0.4, "Safe", np.where(CSS < 0.7, "Warning", "Unsafe")
    )

    # Create results dataframe
    results = pd.DataFrame(
        {
            "True_Label": y_test,
            "Predicted_Label": y_pred,
            "Predicted_Probability": y_proba,
            "Reconstruction_Error": recon_error,
            "CSS": CSS,
            "Safety_Level": safety_labels,
        }
    )

    # Visualize safety distribution
    plt.figure(figsize=(10, 6))
    sns.histplot(data=results, x="CSS", hue="Safety_Level", bins=20, palette="viridis")
    plt.title("Composite Safety Score Distribution")
    plt.xlabel("CSS Score")
    plt.ylabel("Count")
    plt.show()

    # Analyze reconstruction errors
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=recon_error, y=y_proba, hue=y_test, palette="coolwarm")
    plt.title("Reconstruction Error vs. Predicted Probability")
    plt.xlabel("Reconstruction Error")
    plt.ylabel("Abnormality Probability")
    plt.show()

    return results


if __name__ == "__main__":
    results = main()
    print("\nFinal Results Preview:")
    print(results.head())
# Out:
# Epoch 1/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - loss: 1.0220 - val_loss: 1.0164
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.0108 - val_loss: 1.0153
# Epoch 3/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.0088 - val_loss: 1.0150
# Epoch 4/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.0028 - val_loss: 1.0147
# Epoch 5/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.0038 - val_loss: 1.0143
# Epoch 6/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.0010 - val_loss: 1.0145
# Epoch 7/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.9859 - val_loss: 1.0148
# Epoch 8/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.9950 - val_loss: 1.0150
# Epoch 9/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.9955 - val_loss: 1.0150
# Epoch 10/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.9930 - val_loss: 1.0150
# Epoch 11/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.9860 - val_loss: 1.0150
# Epoch 12/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.9767 - val_loss: 1.0149
# Epoch 13/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.9897 - val_loss: 1.0151
# Epoch 14/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.9844 - val_loss: 1.0154
# Epoch 15/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.9772 - val_loss: 1.0152
# Epoch 16/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.9829 - val_loss: 1.0150
# Epoch 17/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.9780 - val_loss: 1.0150
# Epoch 18/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.9773 - val_loss: 1.0152
# Epoch 19/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.9629 - val_loss: 1.0156
# Epoch 20/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.9701 - val_loss: 1.0163
# Epoch 21/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.9713 - val_loss: 1.0170
# Epoch 22/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.9690 - val_loss: 1.0180
# Epoch 23/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.9561 - val_loss: 1.0191
# Epoch 24/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.9604 - val_loss: 1.0201
# Epoch 25/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.9385 - val_loss: 1.0203
# Epoch 26/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.9333 - val_loss: 1.0179
# Epoch 27/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.9438 - val_loss: 1.0144
# Epoch 28/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.9358 - val_loss: 1.0106
# Epoch 29/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.9279 - val_loss: 1.0069
# Epoch 30/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.9219 - val_loss: 1.0030
# Epoch 31/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.9117 - val_loss: 0.9991
# Epoch 32/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.9084 - val_loss: 0.9957
# Epoch 33/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.8993 - val_loss: 0.9927
# Epoch 34/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.8942 - val_loss: 0.9897
# Epoch 35/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.8857 - val_loss: 0.9857
# Epoch 36/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.8709 - val_loss: 0.9817
# Epoch 37/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.8648 - val_loss: 0.9779
# Epoch 38/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.8558 - val_loss: 0.9740
# Epoch 39/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.8352 - val_loss: 0.9656
# Epoch 40/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.8403 - val_loss: 0.9524
# Epoch 41/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.8325 - val_loss: 0.9396
# Epoch 42/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.8200 - val_loss: 0.9302
# Epoch 43/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.8065 - val_loss: 0.9249
# Epoch 44/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.7999 - val_loss: 0.9220
# Epoch 45/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.7984 - val_loss: 0.9196
# Epoch 46/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.7785 - val_loss: 0.9157
# Epoch 47/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.7679 - val_loss: 0.9146
# Epoch 48/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.7751 - val_loss: 0.9203
# Epoch 49/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.7597 - val_loss: 0.9258
# Epoch 50/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.7628 - val_loss: 0.9294
# Epoch 51/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.7521 - val_loss: 0.9337
# Epoch 52/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.7491 - val_loss: 0.9397
# Epoch 53/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.7406 - val_loss: 0.9462
# Epoch 54/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.7266 - val_loss: 0.9537
# Epoch 55/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.7223 - val_loss: 0.9620
# Epoch 56/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.7126 - val_loss: 0.9683
# Epoch 57/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.7086 - val_loss: 0.9709
# Epoch 58/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.6953 - val_loss: 0.9669
# Epoch 59/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6928 - val_loss: 0.9562
# Epoch 60/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.6869 - val_loss: 0.9444
# Epoch 61/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.6791 - val_loss: 0.9326
# Epoch 62/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6779 - val_loss: 0.9296
# Epoch 63/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.6679 - val_loss: 0.9371
# Epoch 64/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.6531 - val_loss: 0.9486
# Epoch 65/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6654 - val_loss: 0.9588
# Epoch 66/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.6666 - val_loss: 0.9592
# Epoch 67/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6630 - val_loss: 0.9307
# Epoch 68/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6513 - val_loss: 0.8933
# Epoch 69/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6431 - val_loss: 0.8647
# Epoch 70/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.6454 - val_loss: 0.8437
# Epoch 71/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6425 - val_loss: 0.8336
# Epoch 72/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6351 - val_loss: 0.8301
# Epoch 73/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.6446 - val_loss: 0.8292
# Epoch 74/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.6401 - val_loss: 0.8305
# Epoch 75/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6410 - val_loss: 0.8342
# Epoch 76/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6350 - val_loss: 0.8433
# Epoch 77/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.6295 - val_loss: 0.8637
# Epoch 78/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.6224 - val_loss: 0.8822
# Epoch 79/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.6248 - val_loss: 0.8917
# Epoch 80/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6229 - val_loss: 0.8977
# Epoch 81/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.6248 - val_loss: 0.8987
# Epoch 82/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6221 - val_loss: 0.8952
# Epoch 83/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6104 - val_loss: 0.8916
# Epoch 84/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6155 - val_loss: 0.8900
# Epoch 85/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6075 - val_loss: 0.8755
# Epoch 86/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.6041 - val_loss: 0.8617
# Epoch 87/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.5944 - val_loss: 0.8599
# Epoch 88/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.6039 - val_loss: 0.8624
# Epoch 89/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.6085 - val_loss: 0.8626
# Epoch 90/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.6001 - val_loss: 0.8599
# Epoch 91/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.6043 - val_loss: 0.8576
# Epoch 92/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.5955 - val_loss: 0.8566
# Epoch 93/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5886 - val_loss: 0.8557
# Epoch 94/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5853 - val_loss: 0.8563
# Epoch 95/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5761 - val_loss: 0.8583
# Epoch 96/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.5784 - val_loss: 0.8603
# Epoch 97/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.5706 - val_loss: 0.8603
# Epoch 98/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5715 - val_loss: 0.8574
# Epoch 99/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.5663 - val_loss: 0.8562
# Epoch 100/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.5630 - val_loss: 0.8583
# Epoch 101/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5517 - val_loss: 0.8605
# Epoch 102/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.5590 - val_loss: 0.8631
# Epoch 103/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5508 - val_loss: 0.8631
# Epoch 104/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5462 - val_loss: 0.8592
# Epoch 105/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5439 - val_loss: 0.8534
# Epoch 106/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.5477 - val_loss: 0.8488
# Epoch 107/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.5376 - val_loss: 0.8397
# Epoch 108/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5384 - val_loss: 0.8285
# Epoch 109/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.5339 - val_loss: 0.8214
# Epoch 110/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.5322 - val_loss: 0.8160
# Epoch 111/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.5323 - val_loss: 0.8118
# Epoch 112/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.5255 - val_loss: 0.8046
# Epoch 113/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.5272 - val_loss: 0.7957
# Epoch 114/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.5197 - val_loss: 0.7909
# Epoch 115/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.5190 - val_loss: 0.7888
# Epoch 116/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.5187 - val_loss: 0.7866
# Epoch 117/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.5145 - val_loss: 0.7853
# Epoch 118/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.5054 - val_loss: 0.7839
# Epoch 119/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.5048 - val_loss: 0.7818
# Epoch 120/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.4993 - val_loss: 0.7816
# Epoch 121/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.4910 - val_loss: 0.7823
# Epoch 122/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.4983 - val_loss: 0.7830
# Epoch 123/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.4978 - val_loss: 0.7857
# Epoch 124/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.4937 - val_loss: 0.7900
# Epoch 125/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.4917 - val_loss: 0.7955
# Epoch 126/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.4779 - val_loss: 0.8016
# Epoch 127/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.4812 - val_loss: 0.8089
# Epoch 128/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.4683 - val_loss: 0.8200
# Epoch 129/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.4717 - val_loss: 0.8354
# Epoch 130/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4687 - val_loss: 0.8502
# Epoch 131/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.4681 - val_loss: 0.8608
# Epoch 132/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4704 - val_loss: 0.8680
# Epoch 133/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4733 - val_loss: 0.8722
# Epoch 134/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4660 - val_loss: 0.8727
# Epoch 135/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4688 - val_loss: 0.8695
# Epoch 136/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4697 - val_loss: 0.8640
# Epoch 137/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.4663 - val_loss: 0.8572
# Epoch 138/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4579 - val_loss: 0.8497
# Epoch 139/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4492 - val_loss: 0.8428
# Epoch 140/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4470 - val_loss: 0.8370
# Epoch 141/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4392 - val_loss: 0.8292
# Epoch 142/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4311 - val_loss: 0.8176
# Epoch 143/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4371 - val_loss: 0.8070
# Epoch 144/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4294 - val_loss: 0.8001
# Epoch 145/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4349 - val_loss: 0.7971
# Epoch 146/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.4361 - val_loss: 0.7968
# Epoch 147/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4348 - val_loss: 0.7974
# Epoch 148/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.4296 - val_loss: 0.7984
# Epoch 149/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.4298 - val_loss: 0.7995
# Epoch 150/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.4237 - val_loss: 0.8003
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62         8
#            1       0.70      0.70      0.70        10
#
#     accuracy                           0.67        18
#    macro avg       0.66      0.66      0.66        18
# weighted avg       0.67      0.67      0.67        18
#
# F1 Score: 0.7000
# AUC-ROC: 0.6250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Final Results Preview:
#     True_Label  Predicted_Label  Predicted_Probability  Reconstruction_Error  \
# 27           1                1               0.977151              1.288828
# 17           1                0               0.003658              1.585292
# 33           0                0               0.007994              0.520414
# 57           0                1               0.981433              1.164107
# 55           1                1               0.684831              0.720853
#
#          CSS Safety_Level
# 27  0.816550       Unsafe
# 17  0.280644         Safe
# 33  0.079645         Safe
# 57  0.795306       Unsafe
# 55  0.529990      Warning

# %%
import joblib

# Save Gradient Boosting model
joblib.dump(gb, "gb_model.pkl")

# Save Scaler
joblib.dump(scaler, "scaler.pkl")

# Save selected features
selected_features = X.columns.tolist()
joblib.dump(selected_features, "selected_features.pkl")

# Save Autoencoder model
autoencoder.save("ae_model.h5")

print("✅ All model components saved successfully!")
