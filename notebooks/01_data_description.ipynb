# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **DATA DESCRIPTION**

# %%
import pandas as pd

# Load the dataset
df_rollator = pd.read_csv("/content/drive/MyDrive/new gait data/final_rollator_exampledata.csv")

# 1. Display basic information
print("Dataset Shape:", df_rollator.shape)
print("\nFirst 5 rows:")
print(df_rollator.head())
print("\nColumns:")
print(df_rollator.columns.tolist())
print("\nData Types:")
print(df_rollator.dtypes)

# 2. Check for missing values
print("\nMissing Values Summary:")
print(df_rollator.isnull().sum())

# 3. Generate descriptive statistics
print("\nDescriptive Statistics:")
print(df_rollator.describe(include='all'))

# 4. Check unique values for categorical columns
print("\nUnique Values Count:")
for column in df_rollator.columns:
    print(f"{column}: {df_rollator[column].nunique()} unique values")

# 5. Temporal data analysis (for time-like columns)
time_columns = [col for col in df_rollator.columns if ':' in str(df_rollator[col].iloc[0])]
if time_columns:
    print("\nTime-related Columns Summary:")
    print(df_rollator[time_columns].describe())

# 6. Correlation analysis (for numerical columns)
numerical_cols = df_rollator.select_dtypes(include=['float64', 'int64']).columns
if not numerical_cols.empty:
    print("\nCorrelation Matrix:")
    print(df_rollator[numerical_cols].corr())
# Out:
# Dataset Shape: (60, 48)
#
# First 5 rows:
#   Regular step WithSlopeup  Regular step WithStrideSlopeup  \
# 0                  15:03.4                            61.0
# 1                  15:04.6                            59.0
# 2                  15:05.9                            63.0
# 3                  15:07.0                            60.0
# 4                  15:08.2                            52.0
#
#    Regular step WithSpeedSlopeup Regular step WithSlopedown  \
# 0                          137.0                    31:51.5
# 1                          122.0                    31:52.8
# 2                          122.0                    31:54.0
# 3                          118.0                    31:55.1
# 4                          116.0                    31:56.2
#
#    Regular step WithStrideSlopedown  Regular step WithSpeedSlopdown  \
# 0                              50.0                           118.0
# 1                              47.0                           127.0
# 2                              42.0                           122.0
# 3                              39.0                           110.0
# 4                              32.0                           108.0
#
#   Regular step WithGravel  Regular step WithStrideGravel  \
# 0                 04:47.7                           49.0
# 1                 04:48.9                           52.0
# 2                 04:50.1                           51.0
# 3                 04:51.3                           49.0
# 4                 04:52.4                           53.0
#
#    Regular step WithSpeedGravel Regular step WithSidewalk  ...  \
# 0                         116.0                   10:42.4  ...
# 1                         118.0                   10:43.5  ...
# 2                         118.0                   10:44.7  ...
# 3                         120.0                   10:45.9  ...
# 4                         116.0                   10:47.0  ...
#
#    Regular step withoutwalkspeedgravel  Regular step Withoutwalkspeedsidewalk  \
# 0                             0.796610                               0.849057
# 1                             1.225806                               0.796296
# 2                             1.066667                               0.851852
# 3                             0.980392                               0.888889
# 4                             0.870370                               0.796296
#
#    Acceleration WithoutSlopeup.1  Acceleration WithoutAverageZSlopeup  \
# 0                       14:40:07                             0.205800
# 1                       14:40:08                             0.202206
# 2                       14:40:09                             0.202392
# 3                       14:40:10                             0.205800
# 4                       14:40:11                             0.205800
#
#    Acceleration WithoutSlopedown.1  Acceleration WithoutAverageZSlopedown  \
# 0                         05:04:52                               0.205800
# 1                         05:05:07                               0.213333
# 2                         05:05:03                               0.205800
# 3                         05:05:19                               0.190658
# 4                         05:06:19                               0.220588
#
#   Acceleration WithoutGravel.1  Acceleration WithoutAverageZGravel  \
# 0                     14:30:13                            0.171123
# 1                     14:30:14                            0.209524
# 2                     14:30:15                            0.194175
# 3                     14:30:16                            0.202206
# 4                     14:30:17                            0.209524
#
#   Acceleration WithoutSidewalk.1  Acceleration WithoutAverageZSidewalk
# 0                        46:00.0                              0.220588
# 1                        46:01.1                              0.202392
# 2                        46:02.1                              0.220588
# 3                        46:03.2                              0.220588
# 4                        46:04.3                              0.202392
#
# [5 rows x 48 columns]
#
# Columns:
# ['Regular step WithSlopeup', 'Regular step WithStrideSlopeup', 'Regular step WithSpeedSlopeup', 'Regular step WithSlopedown', 'Regular step WithStrideSlopedown', 'Regular step WithSpeedSlopdown', 'Regular step WithGravel', 'Regular step WithStrideGravel', 'Regular step WithSpeedGravel', 'Regular step WithSidewalk', 'Regular step WithStrideSidwalk', 'Regular step WithSpeedSidewalk', 'Regular step Walking speedslopdown', 'Regular step Walking speed slopeup', 'Regular step Walking speed gravel', 'Regular step Walking speed sidewalk', 'Acceleration WithSlopeup.1', 'Acceleration WithAverageZSlopeup', 'Acceleration WithSlopedown.1', 'Acceleration WithAverageZSlopedown', 'Acceleration WithGravel.1', 'Acceleration WithAverageZGravel', 'Acceleration WithSidewalk.1', 'Acceleration WithAverageZSidewalk', 'Regular step WithoutSlopeup', 'Regular step WithoutStrideSlopeup', 'Regular step WithoutSpeedSlopeup', 'Regular step WithoutSlopedown', 'Regular step WithoutStrideSlopedown', 'Regular step WithoutSpeedSlopedown', 'Regular step WithoutGravel', 'Regular step WithoutStrideGravel', 'Regular step WithoutSpeedGravel', 'Regular step WithoutSidewalk', 'Regular step WithoutStrideSidewalk', 'Regular step WithoutSpeedSidewalk', 'Regular step Withoutwspeed slopup', 'Regular step withoutspeedslopedown', 'Regular step withoutwalkspeedgravel', 'Regular step Withoutwalkspeedsidewalk', 'Acceleration WithoutSlopeup.1', 'Acceleration WithoutAverageZSlopeup', 'Acceleration WithoutSlopedown.1', 'Acceleration WithoutAverageZSlopedown', 'Acceleration WithoutGravel.1', 'Acceleration WithoutAverageZGravel', 'Acceleration WithoutSidewalk.1', 'Acceleration WithoutAverageZSidewalk']
#
# Data Types:
# Regular step WithSlopeup                  object
# Regular step WithStrideSlopeup           float64
# Regular step WithSpeedSlopeup            float64
# Regular step WithSlopedown                object
# Regular step WithStrideSlopedown         float64
# Regular step WithSpeedSlopdown           float64
# Regular step WithGravel                   object
# Regular step WithStrideGravel            float64
# Regular step WithSpeedGravel             float64
# Regular step WithSidewalk                 object
# Regular step WithStrideSidwalk           float64
# Regular step WithSpeedSidewalk           float64
# Regular step Walking speedslopdown       float64
# Regular step Walking speed slopeup       float64
# Regular step Walking speed gravel        float64
# Regular step Walking speed sidewalk      float64
# Acceleration WithSlopeup.1                object
# Acceleration WithAverageZSlopeup         float64
# Acceleration WithSlopedown.1              object
# Acceleration WithAverageZSlopedown       float64
# Acceleration WithGravel.1                 object
# Acceleration WithAverageZGravel          float64
# Acceleration WithSidewalk.1               object
# Acceleration WithAverageZSidewalk        float64
# Regular step WithoutSlopeup               object
# Regular step WithoutStrideSlopeup        float64
# Regular step WithoutSpeedSlopeup         float64
# Regular step WithoutSlopedown             object
# Regular step WithoutStrideSlopedown      float64
# Regular step WithoutSpeedSlopedown       float64
# Regular step WithoutGravel                object
# Regular step WithoutStrideGravel         float64
# Regular step WithoutSpeedGravel          float64
# Regular step WithoutSidewalk              object
# Regular step WithoutStrideSidewalk       float64
# Regular step WithoutSpeedSidewalk        float64
# Regular step Withoutwspeed slopup        float64
# Regular step withoutspeedslopedown       float64
# Regular step withoutwalkspeedgravel      float64
# Regular step Withoutwalkspeedsidewalk    float64
# Acceleration WithoutSlopeup.1             object
# Acceleration WithoutAverageZSlopeup      float64
# Acceleration WithoutSlopedown.1           object
# Acceleration WithoutAverageZSlopedown    float64
# Acceleration WithoutGravel.1              object
# Acceleration WithoutAverageZGravel       float64
# Acceleration WithoutSidewalk.1            object
# Acceleration WithoutAverageZSidewalk     float64
# dtype: object
#
# Missing Values Summary:
# Regular step WithSlopeup                 22
# Regular step WithStrideSlopeup           22
# Regular step WithSpeedSlopeup            22
# Regular step WithSlopedown               41
# Regular step WithStrideSlopedown         41
# Regular step WithSpeedSlopdown           41
# Regular step WithGravel                   2
# Regular step WithStrideGravel             2
# Regular step WithSpeedGravel              2
# Regular step WithSidewalk                24
# Regular step WithStrideSidwalk           24
# Regular step WithSpeedSidewalk           24
# Regular step Walking speedslopdown       39
# Regular step Walking speed slopeup       20
# Regular step Walking speed gravel         0
# Regular step Walking speed sidewalk      22
# Acceleration WithSlopeup.1               22
# Acceleration WithAverageZSlopeup         22
# Acceleration WithSlopedown.1             41
# Acceleration WithAverageZSlopedown       40
# Acceleration WithGravel.1                 2
# Acceleration WithAverageZGravel           2
# Acceleration WithSidewalk.1              24
# Acceleration WithAverageZSidewalk        24
# Regular step WithoutSlopeup              16
# Regular step WithoutStrideSlopeup        16
# Regular step WithoutSpeedSlopeup         16
# Regular step WithoutSlopedown            23
# Regular step WithoutStrideSlopedown      23
# Regular step WithoutSpeedSlopedown       23
# Regular step WithoutGravel               27
# Regular step WithoutStrideGravel         27
# Regular step WithoutSpeedGravel          27
# Regular step WithoutSidewalk             17
# Regular step WithoutStrideSidewalk       17
# Regular step WithoutSpeedSidewalk        17
# Regular step Withoutwspeed slopup        16
# Regular step withoutspeedslopedown       21
# Regular step withoutwalkspeedgravel      25
# Regular step Withoutwalkspeedsidewalk    15
# Acceleration WithoutSlopeup.1            16
# Acceleration WithoutAverageZSlopeup      15
# Acceleration WithoutSlopedown.1          25
# Acceleration WithoutAverageZSlopedown    25
# Acceleration WithoutGravel.1             28
# Acceleration WithoutAverageZGravel       28
# Acceleration WithoutSidewalk.1           17
# Acceleration WithoutAverageZSidewalk     17
# dtype: int64
#
# Descriptive Statistics:
#        Regular step WithSlopeup  Regular step WithStrideSlopeup  \
# count                        38                       38.000000
# unique                       38                             NaN
# top                     15:03.4                             NaN
# freq                          1                             NaN
# mean                        NaN                       62.842105
# std                         NaN                        5.299293
# min                         NaN                       52.000000
# 25%                         NaN                       59.250000
# 50%                         NaN                       62.000000
# 75%                         NaN                       67.000000
# max                         NaN                       74.000000
#
#         Regular step WithSpeedSlopeup Regular step WithSlopedown  \
# count                       38.000000                         19
# unique                            NaN                         19
# top                               NaN                    31:51.5
# freq                              NaN                          1
# mean                       119.578947                        NaN
# std                          5.875426                        NaN
# min                        104.000000                        NaN
# 25%                        116.000000                        NaN
# 50%                        118.000000                        NaN
# 75%                        122.000000                        NaN
# max                        137.000000                        NaN
#
#         Regular step WithStrideSlopedown  Regular step WithSpeedSlopdown  \
# count                          19.000000                       19.000000
# unique                               NaN                             NaN
# top                                  NaN                             NaN
# freq                                 NaN                             NaN
# mean                           38.421053                      114.157895
# std                             7.081398                        4.645944
# min                            31.000000                      108.000000
# 25%                            33.000000                      110.000000
# 50%                            35.000000                      114.000000
# 75%                            43.000000                      116.000000
# max                            52.000000                      127.000000
#
#        Regular step WithGravel  Regular step WithStrideGravel  \
# count                       58                      58.000000
# unique                      58                            NaN
# top                    04:47.7                            NaN
# freq                         1                            NaN
# mean                       NaN                      51.155172
# std                        NaN                       2.100975
# min                        NaN                      47.000000
# 25%                        NaN                      50.000000
# 50%                        NaN                      51.000000
# 75%                        NaN                      52.000000
# max                        NaN                      60.000000
#
#         Regular step WithSpeedGravel Regular step WithSidewalk  ...  \
# count                      58.000000                        36  ...
# unique                           NaN                        36  ...
# top                              NaN                   10:42.4  ...
# freq                             NaN                         1  ...
# mean                      117.206897                       NaN  ...
# std                         2.511438                       NaN  ...
# min                       112.000000                       NaN  ...
# 25%                       116.000000                       NaN  ...
# 50%                       116.000000                       NaN  ...
# 75%                       119.500000                       NaN  ...
# max                       124.000000                       NaN  ...
#
#         Regular step withoutwalkspeedgravel  \
# count                             35.000000
# unique                                  NaN
# top                                     NaN
# freq                                    NaN
# mean                               0.913711
# std                                0.125944
# min                                0.528302
# 25%                                0.870370
# 50%                                0.924528
# 75%                                0.981307
# max                                1.225806
#
#         Regular step Withoutwalkspeedsidewalk  Acceleration WithoutSlopeup.1  \
# count                               45.000000                             44
# unique                                    NaN                             44
# top                                       NaN                       14:40:07
# freq                                      NaN                              1
# mean                                 0.812660                            NaN
# std                                  0.036631                            NaN
# min                                  0.740741                            NaN
# 25%                                  0.781818                            NaN
# 50%                                  0.812580                            NaN
# 75%                                  0.833333                            NaN
# max                                  0.888889                            NaN
#
#         Acceleration WithoutAverageZSlopeup  Acceleration WithoutSlopedown.1  \
# count                             45.000000                               35
# unique                                  NaN                               33
# top                                     NaN                         05:12:14
# freq                                    NaN                                2
# mean                               0.209867                              NaN
# std                                0.010840                              NaN
# min                                0.187091                              NaN
# 25%                                0.205800                              NaN
# 50%                                0.209524                              NaN
# 75%                                0.213592                              NaN
# max                                0.243218                              NaN
#
#         Acceleration WithoutAverageZSlopedown Acceleration WithoutGravel.1  \
# count                               35.000000                           32
# unique                                    NaN                           32
# top                                       NaN                     14:30:13
# freq                                      NaN                            1
# mean                                 0.211709                          NaN
# std                                  0.013152                          NaN
# min                                  0.183824                          NaN
# 25%                                  0.204096                          NaN
# 50%                                  0.209724                          NaN
# 75%                                  0.220588                          NaN
# max                                  0.239190                          NaN
#
#         Acceleration WithoutAverageZGravel Acceleration WithoutSidewalk.1  \
# count                            32.000000                             43
# unique                                 NaN                             43
# top                                    NaN                        46:00.0
# freq                                   NaN                              1
# mean                              0.199245                            NaN
# std                               0.017010                            NaN
# min                               0.171123                            NaN
# 25%                               0.187266                            NaN
# 50%                               0.202206                            NaN
# 75%                               0.205993                            NaN
# max                               0.262172                            NaN
#
#         Acceleration WithoutAverageZSidewalk
# count                              43.000000
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                                0.210205
# std                                 0.008260
# min                                 0.195382
# 25%                                 0.202299
# 50%                                 0.213144
# 75%                                 0.216998
# max                                 0.220791
#
# [11 rows x 48 columns]
#
# Unique Values Count:
# Regular step WithSlopeup: 38 unique values
# Regular step WithStrideSlopeup: 18 unique values
# Regular step WithSpeedSlopeup: 9 unique values
# Regular step WithSlopedown: 19 unique values
# Regular step WithStrideSlopedown: 12 unique values
# Regular step WithSpeedSlopdown: 8 unique values
# Regular step WithGravel: 58 unique values
# Regular step WithStrideGravel: 10 unique values
# Regular step WithSpeedGravel: 7 unique values
# Regular step WithSidewalk: 36 unique values
# Regular step WithStrideSidwalk: 15 unique values
# Regular step WithSpeedSidewalk: 10 unique values
# Regular step Walking speedslopdown: 19 unique values
# Regular step Walking speed slopeup: 34 unique values
# Regular step Walking speed gravel: 30 unique values
# Regular step Walking speed sidewalk: 31 unique values
# Acceleration WithSlopeup.1: 38 unique values
# Acceleration WithAverageZSlopeup: 21 unique values
# Acceleration WithSlopedown.1: 19 unique values
# Acceleration WithAverageZSlopedown: 13 unique values
# Acceleration WithGravel.1: 58 unique values
# Acceleration WithAverageZGravel: 19 unique values
# Acceleration WithSidewalk.1: 36 unique values
# Acceleration WithAverageZSidewalk: 19 unique values
# Regular step WithoutSlopeup: 44 unique values
# Regular step WithoutStrideSlopeup: 9 unique values
# Regular step WithoutSpeedSlopeup: 7 unique values
# Regular step WithoutSlopedown: 37 unique values
# Regular step WithoutStrideSlopedown: 17 unique values
# Regular step WithoutSpeedSlopedown: 7 unique values
# Regular step WithoutGravel: 33 unique values
# Regular step WithoutStrideGravel: 15 unique values
# Regular step WithoutSpeedGravel: 10 unique values
# Regular step WithoutSidewalk: 43 unique values
# Regular step WithoutStrideSidewalk: 9 unique values
# Regular step WithoutSpeedSidewalk: 4 unique values
# Regular step Withoutwspeed slopup: 25 unique values
# Regular step withoutspeedslopedown: 30 unique values
# Regular step withoutwalkspeedgravel: 29 unique values
# Regular step Withoutwalkspeedsidewalk: 26 unique values
# Acceleration WithoutSlopeup.1: 44 unique values
# Acceleration WithoutAverageZSlopeup: 18 unique values
# Acceleration WithoutSlopedown.1: 33 unique values
# Acceleration WithoutAverageZSlopedown: 22 unique values
# Acceleration WithoutGravel.1: 32 unique values
# Acceleration WithoutAverageZGravel: 18 unique values
# Acceleration WithoutSidewalk.1: 43 unique values
# Acceleration WithoutAverageZSidewalk: 12 unique values
#
# Time-related Columns Summary:
#        Regular step WithSlopeup Regular step WithSlopedown  \
# count                        38                         19
# unique                       38                         19
# top                     15:03.4                    31:51.5
# freq                          1                          1
#
#        Regular step WithGravel Regular step WithSidewalk  \
# count                       58                        36
# unique                      58                        36
# top                    04:47.7                   10:42.4
# freq                         1                         1
#
#        Acceleration WithSlopeup.1 Acceleration WithSlopedown.1  \
# count                          38                           19
# unique                         38                           19
# top                       15:03.4                      31:51.5
# freq                            1                            1
#
#        Acceleration WithGravel.1 Acceleration WithSidewalk.1  \
# count                         58                          36
# unique                        58                          36
# top                      04:47.7                     10:42.4
# freq                           1                           1
#
#        Regular step WithoutSlopeup Regular step WithoutSlopedown  \
# count                           44                            37
# unique                          44                            37
# top                       14:40:06                      14:54:12
# freq                             1                             1
#
#        Regular step WithoutGravel Regular step WithoutSidewalk  \
# count                          33                           43
# unique                         33                           43
# top                      14:30:12                     14:45:59
# freq                            1                            1
#
#        Acceleration WithoutSlopeup.1 Acceleration WithoutSlopedown.1  \
# count                             44                              35
# unique                            44                              33
# top                         14:40:07                        05:12:14
# freq                               1                               2
#
#        Acceleration WithoutGravel.1 Acceleration WithoutSidewalk.1
# count                            32                             43
# unique                           32                             43
# top                        14:30:13                        46:00.0
# freq                              1                              1
#
# Correlation Matrix:
#                                        Regular step WithStrideSlopeup  \
# Regular step WithStrideSlopeup                               1.000000
# Regular step WithSpeedSlopeup                                0.055966
# Regular step WithStrideSlopedown                            -0.091330
# Regular step WithSpeedSlopdown                               0.226862
# Regular step WithStrideGravel                               -0.154025
# Regular step WithSpeedGravel                                -0.239788
# Regular step WithStrideSidwalk                              -0.331123
# Regular step WithSpeedSidewalk                               0.265232
# Regular step Walking speedslopdown                          -0.140236
# Regular step Walking speed slopeup                           0.858506
# Regular step Walking speed gravel                           -0.024933
# Regular step Walking speed sidewalk                         -0.329843
# Acceleration WithAverageZSlopeup                             0.185196
# Acceleration WithAverageZSlopedown                          -0.244858
# Acceleration WithAverageZGravel                              0.284747
# Acceleration WithAverageZSidewalk                           -0.543299
# Regular step WithoutStrideSlopeup                           -0.051254
# Regular step WithoutSpeedSlopeup                            -0.426401
# Regular step WithoutStrideSlopedown                         -0.581855
# Regular step WithoutSpeedSlopedown                          -0.507448
# Regular step WithoutStrideGravel                            -0.286372
# Regular step WithoutSpeedGravel                              0.159051
# Regular step WithoutStrideSidewalk                          -0.383529
# Regular step WithoutSpeedSidewalk                           -0.114488
# Regular step Withoutwspeed slopup                            0.103931
# Regular step withoutspeedslopedown                          -0.463277
# Regular step withoutwalkspeedgravel                         -0.274885
# Regular step Withoutwalkspeedsidewalk                       -0.353128
# Acceleration WithoutAverageZSlopeup                          0.283768
# Acceleration WithoutAverageZSlopedown                        0.170705
# Acceleration WithoutAverageZGravel                           0.127201
# Acceleration WithoutAverageZSidewalk                        -0.111769
#
#                                        Regular step WithSpeedSlopeup  \
# Regular step WithStrideSlopeup                              0.055966
# Regular step WithSpeedSlopeup                               1.000000
# Regular step WithStrideSlopedown                            0.546306
# Regular step WithSpeedSlopdown                              0.431988
# Regular step WithStrideGravel                              -0.189162
# Regular step WithSpeedGravel                               -0.212951
# Regular step WithStrideSidwalk                             -0.150070
# Regular step WithSpeedSidewalk                              0.027698
# Regular step Walking speedslopdown                          0.489789
# Regular step Walking speed slopeup                         -0.458561
# Regular step Walking speed gravel                          -0.076785
# Regular step Walking speed sidewalk                        -0.095567
# Acceleration WithAverageZSlopeup                           -0.243187
# Acceleration WithAverageZSlopedown                         -0.530466
# Acceleration WithAverageZGravel                             0.054648
# Acceleration WithAverageZSidewalk                          -0.268431
# Regular step WithoutStrideSlopeup                           0.195071
# Regular step WithoutSpeedSlopeup                           -0.154504
# Regular step WithoutStrideSlopedown                         0.003708
# Regular step WithoutSpeedSlopedown                          0.012074
# Regular step WithoutStrideGravel                           -0.024960
# Regular step WithoutSpeedGravel                             0.144356
# Regular step WithoutStrideSidewalk                         -0.077797
# Regular step WithoutSpeedSidewalk                          -0.314568
# Regular step Withoutwspeed slopup                           0.217572
# Regular step withoutspeedslopedown                          0.000266
# Regular step withoutwalkspeedgravel                        -0.046503
# Regular step Withoutwalkspeedsidewalk                       0.029093
# Acceleration WithoutAverageZSlopeup                        -0.027455
# Acceleration WithoutAverageZSlopedown                      -0.022071
# Acceleration WithoutAverageZGravel                         -0.065421
# Acceleration WithoutAverageZSidewalk                        0.005034
#
#                                        Regular step WithStrideSlopedown  \
# Regular step WithStrideSlopeup                                -0.091330
# Regular step WithSpeedSlopeup                                  0.546306
# Regular step WithStrideSlopedown                               1.000000
# Regular step WithSpeedSlopdown                                 0.550049
# Regular step WithStrideGravel                                 -0.276477
# Regular step WithSpeedGravel                                   0.210728
# Regular step WithStrideSidwalk                                -0.651349
# Regular step WithSpeedSidewalk                                -0.093524
# Regular step Walking speedslopdown                             0.977422
# Regular step Walking speed slopeup                            -0.441907
# Regular step Walking speed gravel                             -0.390954
# Regular step Walking speed sidewalk                           -0.509105
# Acceleration WithAverageZSlopeup                              -0.153694
# Acceleration WithAverageZSlopedown                            -0.264248
# Acceleration WithAverageZGravel                                0.247174
# Acceleration WithAverageZSidewalk                              0.131386
# Regular step WithoutStrideSlopeup                              0.245781
# Regular step WithoutSpeedSlopeup                               0.134502
# Regular step WithoutStrideSlopedown                           -0.479272
# Regular step WithoutSpeedSlopedown                             0.280774
# Regular step WithoutStrideGravel                               0.074911
# Regular step WithoutSpeedGravel                                0.034986
# Regular step WithoutStrideSidewalk                             0.201034
# Regular step WithoutSpeedSidewalk                             -0.069187
# Regular step Withoutwspeed slopup                              0.194851
# Regular step withoutspeedslopedown                            -0.531280
# Regular step withoutwalkspeedgravel                            0.078135
# Regular step Withoutwalkspeedsidewalk                          0.208806
# Acceleration WithoutAverageZSlopeup                           -0.388350
# Acceleration WithoutAverageZSlopedown                          0.476998
# Acceleration WithoutAverageZGravel                            -0.568440
# Acceleration WithoutAverageZSidewalk                           0.227115
#
#                                        Regular step WithSpeedSlopdown  \
# Regular step WithStrideSlopeup                               0.226862
# Regular step WithSpeedSlopeup                                0.431988
# Regular step WithStrideSlopedown                             0.550049
# Regular step WithSpeedSlopdown                               1.000000
# Regular step WithStrideGravel                               -0.088090
# Regular step WithSpeedGravel                                -0.096756
# Regular step WithStrideSidwalk                              -0.050050
# Regular step WithSpeedSidewalk                              -0.033007
# Regular step Walking speedslopdown                           0.362129
# Regular step Walking speed slopeup                          -0.100139
# Regular step Walking speed gravel                           -0.043441
# Regular step Walking speed sidewalk                         -0.026746
# Acceleration WithAverageZSlopeup                            -0.618688
# Acceleration WithAverageZSlopedown                          -0.648824
# Acceleration WithAverageZGravel                              0.035777
# Acceleration WithAverageZSidewalk                            0.193935
# Regular step WithoutStrideSlopeup                            0.110095
# Regular step WithoutSpeedSlopeup                            -0.024861
# Regular step WithoutStrideSlopedown                         -0.174064
# Regular step WithoutSpeedSlopedown                          -0.205749
# Regular step WithoutStrideGravel                             0.271140
# Regular step WithoutSpeedGravel                             -0.347382
# Regular step WithoutStrideSidewalk                          -0.158775
# Regular step WithoutSpeedSidewalk                           -0.160137
# Regular step Withoutwspeed slopup                            0.110789
# Regular step withoutspeedslopedown                          -0.103160
# Regular step withoutwalkspeedgravel                          0.395675
# Regular step Withoutwalkspeedsidewalk                       -0.098149
# Acceleration WithoutAverageZSlopeup                         -0.105132
# Acceleration WithoutAverageZSlopedown                        0.095025
# Acceleration WithoutAverageZGravel                          -0.252382
# Acceleration WithoutAverageZSidewalk                        -0.047799
#
#                                        Regular step WithStrideGravel  \
# Regular step WithStrideSlopeup                             -0.154025
# Regular step WithSpeedSlopeup                              -0.189162
# Regular step WithStrideSlopedown                           -0.276477
# Regular step WithSpeedSlopdown                             -0.088090
# Regular step WithStrideGravel                               1.000000
# Regular step WithSpeedGravel                                0.316326
# Regular step WithStrideSidwalk                              0.032648
# Regular step WithSpeedSidewalk                             -0.061474
# Regular step Walking speedslopdown                         -0.265929
# Regular step Walking speed slopeup                         -0.044143
# Regular step Walking speed gravel                           0.857251
# Regular step Walking speed sidewalk                         0.036390
# Acceleration WithAverageZSlopeup                           -0.054951
# Acceleration WithAverageZSlopedown                          0.326642
# Acceleration WithAverageZGravel                            -0.170255
# Acceleration WithAverageZSidewalk                           0.115716
# Regular step WithoutStrideSlopeup                          -0.162655
# Regular step WithoutSpeedSlopeup                           -0.227576
# Regular step WithoutStrideSlopedown                         0.091063
# Regular step WithoutSpeedSlopedown                         -0.095387
# Regular step WithoutStrideGravel                           -0.071816
# Regular step WithoutSpeedGravel                            -0.134098
# Regular step WithoutStrideSidewalk                          0.035813
# Regular step WithoutSpeedSidewalk                           0.082528
# Regular step Withoutwspeed slopup                          -0.061881
# Regular step withoutspeedslopedown                          0.109564
# Regular step withoutwalkspeedgravel                        -0.032194
# Regular step Withoutwalkspeedsidewalk                       0.004404
# Acceleration WithoutAverageZSlopeup                         0.225396
# Acceleration WithoutAverageZSlopedown                      -0.194136
# Acceleration WithoutAverageZGravel                          0.074736
# Acceleration WithoutAverageZSidewalk                        0.068248
#
#                                        Regular step WithSpeedGravel  \
# Regular step WithStrideSlopeup                            -0.239788
# Regular step WithSpeedSlopeup                             -0.212951
# Regular step WithStrideSlopedown                           0.210728
# Regular step WithSpeedSlopdown                            -0.096756
# Regular step WithStrideGravel                              0.316326
# Regular step WithSpeedGravel                               1.000000
# Regular step WithStrideSidwalk                             0.038965
# Regular step WithSpeedSidewalk                            -0.138254
# Regular step Walking speedslopdown                         0.229396
# Regular step Walking speed slopeup                        -0.112690
# Regular step Walking speed gravel                         -0.216757
# Regular step Walking speed sidewalk                        0.061989
# Acceleration WithAverageZSlopeup                          -0.063238
# Acceleration WithAverageZSlopedown                         0.312716
# Acceleration WithAverageZGravel                           -0.030106
# Acceleration WithAverageZSidewalk                          0.286583
# Regular step WithoutStrideSlopeup                          0.064559
# Regular step WithoutSpeedSlopeup                           0.062305
# Regular step WithoutStrideSlopedown                        0.025312
# Regular step WithoutSpeedSlopedown                         0.089994
# Regular step WithoutStrideGravel                          -0.062624
# Regular step WithoutSpeedGravel                           -0.089675
# Regular step WithoutStrideSidewalk                         0.302081
# Regular step WithoutSpeedSidewalk                          0.286703
# Regular step Withoutwspeed slopup                          0.036923
# Regular step withoutspeedslopedown                         0.013575
# Regular step withoutwalkspeedgravel                       -0.035032
# Regular step Withoutwalkspeedsidewalk                      0.203955
# Acceleration WithoutAverageZSlopeup                        0.258195
# Acceleration WithoutAverageZSlopedown                      0.173731
# Acceleration WithoutAverageZGravel                        -0.110172
# Acceleration WithoutAverageZSidewalk                       0.140305
#
#                                        Regular step WithStrideSidwalk  \
# Regular step WithStrideSlopeup                              -0.331123
# Regular step WithSpeedSlopeup                               -0.150070
# Regular step WithStrideSlopedown                            -0.651349
# Regular step WithSpeedSlopdown                              -0.050050
# Regular step WithStrideGravel                                0.032648
# Regular step WithSpeedGravel                                 0.038965
# Regular step WithStrideSidwalk                               1.000000
# Regular step WithSpeedSidewalk                              -0.591196
# Regular step Walking speedslopdown                          -0.668715
# Regular step Walking speed slopeup                          -0.202514
# Regular step Walking speed gravel                            0.013049
# Regular step Walking speed sidewalk                          0.979702
# Acceleration WithAverageZSlopeup                            -0.049367
# Acceleration WithAverageZSlopedown                          -0.204444
# Acceleration WithAverageZGravel                             -0.388218
# Acceleration WithAverageZSidewalk                            0.722133
# Regular step WithoutStrideSlopeup                            0.135345
# Regular step WithoutSpeedSlopeup                             0.042921
# Regular step WithoutStrideSlopedown                          0.284275
# Regular step WithoutSpeedSlopedown                          -0.213037
# Regular step WithoutStrideGravel                             0.674544
# Regular step WithoutSpeedGravel                             -0.205530
# Regular step WithoutStrideSidewalk                           0.182357
# Regular step WithoutSpeedSidewalk                           -0.107085
# Regular step Withoutwspeed slopup                            0.101097
# Regular step withoutspeedslopedown                           0.325192
# Regular step withoutwalkspeedgravel                          0.544856
# Regular step Withoutwalkspeedsidewalk                        0.223330
# Acceleration WithoutAverageZSlopeup                          0.075884
# Acceleration WithoutAverageZSlopedown                       -0.248471
# Acceleration WithoutAverageZGravel                          -0.371073
# Acceleration WithoutAverageZSidewalk                         0.249092
#
#                                        Regular step WithSpeedSidewalk  \
# Regular step WithStrideSlopeup                               0.265232
# Regular step WithSpeedSlopeup                                0.027698
# Regular step WithStrideSlopedown                            -0.093524
# Regular step WithSpeedSlopdown                              -0.033007
# Regular step WithStrideGravel                               -0.061474
# Regular step WithSpeedGravel                                -0.138254
# Regular step WithStrideSidwalk                              -0.591196
# Regular step WithSpeedSidewalk                               1.000000
# Regular step Walking speedslopdown                          -0.092278
# Regular step Walking speed slopeup                           0.222805
# Regular step Walking speed gravel                            0.014958
# Regular step Walking speed sidewalk                         -0.728066
# Acceleration WithAverageZSlopeup                             0.003542
# Acceleration WithAverageZSlopedown                           0.054237
# Acceleration WithAverageZGravel                              0.241327
# Acceleration WithAverageZSidewalk                           -0.576712
# Regular step WithoutStrideSlopeup                           -0.140250
# Regular step WithoutSpeedSlopeup                             0.114644
# Regular step WithoutStrideSlopedown                         -0.151051
# Regular step WithoutSpeedSlopedown                           0.050645
# Regular step WithoutStrideGravel                            -0.339027
# Regular step WithoutSpeedGravel                              0.287388
# Regular step WithoutStrideSidewalk                          -0.045185
# Regular step WithoutSpeedSidewalk                            0.039185
# Regular step Withoutwspeed slopup                           -0.161844
# Regular step withoutspeedslopedown                          -0.160994
# Regular step withoutwalkspeedgravel                         -0.319895
# Regular step Withoutwalkspeedsidewalk                       -0.059570
# Acceleration WithoutAverageZSlopeup                         -0.013563
# Acceleration WithoutAverageZSlopedown                        0.044598
# Acceleration WithoutAverageZGravel                           0.475885
# Acceleration WithoutAverageZSidewalk                        -0.127884
#
#                                        Regular step Walking speedslopdown  \
# Regular step WithStrideSlopeup                                  -0.140236
# Regular step WithSpeedSlopeup                                    0.489789
# Regular step WithStrideSlopedown                                 0.977422
# Regular step WithSpeedSlopdown                                   0.362129
# Regular step WithStrideGravel                                   -0.265929
# Regular step WithSpeedGravel                                     0.229396
# Regular step WithStrideSidwalk                                  -0.668715
# Regular step WithSpeedSidewalk                                  -0.092278
# Regular step Walking speedslopdown                               1.000000
# Regular step Walking speed slopeup                              -0.445895
# Regular step Walking speed gravel                               -0.405129
# Regular step Walking speed sidewalk                             -0.539601
# Acceleration WithAverageZSlopeup                                -0.012000
# Acceleration WithAverageZSlopedown                              -0.127903
# Acceleration WithAverageZGravel                                  0.259288
# Acceleration WithAverageZSidewalk                                0.072992
# Regular step WithoutStrideSlopeup                                0.234059
# Regular step WithoutSpeedSlopeup                                 0.136485
# Regular step WithoutStrideSlopedown                             -0.408986
# Regular step WithoutSpeedSlopedown                               0.354114
# Regular step WithoutStrideGravel                                 0.011278
# Regular step WithoutSpeedGravel                                  0.125752
# Regular step WithoutStrideSidewalk                               0.264950
# Regular step WithoutSpeedSidewalk                               -0.028425
# Regular step Withoutwspeed slopup                                0.173807
# Regular step withoutspeedslopedown                              -0.470364
# Regular step withoutwalkspeedgravel                             -0.015745
# Regular step Withoutwalkspeedsidewalk                            0.258713
# Acceleration WithoutAverageZSlopeup                             -0.373100
# Acceleration WithoutAverageZSlopedown                            0.488411
# Acceleration WithoutAverageZGravel                              -0.551333
# Acceleration WithoutAverageZSidewalk                             0.260450
#
#                                        Regular step Walking speed slopeup  \
# Regular step WithStrideSlopeup                                   0.858506
# Regular step WithSpeedSlopeup                                   -0.458561
# Regular step WithStrideSlopedown                                -0.441907
# Regular step WithSpeedSlopdown                                  -0.100139
# Regular step WithStrideGravel                                   -0.044143
# Regular step WithSpeedGravel                                    -0.112690
# Regular step WithStrideSidwalk                                  -0.202514
# Regular step WithSpeedSidewalk                                   0.222805
# Regular step Walking speedslopdown                              -0.445895
# Regular step Walking speed slopeup                               1.000000
# Regular step Walking speed gravel                                0.019187
# Regular step Walking speed sidewalk                             -0.247812
# Acceleration WithAverageZSlopeup                                 0.287896
# Acceleration WithAverageZSlopedown                               0.116349
# Acceleration WithAverageZGravel                                  0.204805
# Acceleration WithAverageZSidewalk                               -0.325611
# Regular step WithoutStrideSlopeup                               -0.131452
# Regular step WithoutSpeedSlopeup                                -0.297711
# Regular step WithoutStrideSlopedown                             -0.492019
# ...
# Regular step Withoutwalkspeedsidewalk                            0.152595
# Acceleration WithoutAverageZSlopeup                             -0.067368
# Acceleration WithoutAverageZSlopedown                           -0.443944
# Acceleration WithoutAverageZGravel                              -0.041194
# Acceleration WithoutAverageZSidewalk                             0.099748
#
#                                        Regular step withoutwalkspeedgravel  \
# Regular step WithStrideSlopeup                                   -0.274885
# Regular step WithSpeedSlopeup                                    -0.046503
# Regular step WithStrideSlopedown                                  0.078135
# Regular step WithSpeedSlopdown                                    0.395675
# Regular step WithStrideGravel                                    -0.032194
# Regular step WithSpeedGravel                                     -0.035032
# Regular step WithStrideSidwalk                                    0.544856
# Regular step WithSpeedSidewalk                                   -0.319895
# Regular step Walking speedslopdown                               -0.015745
# Regular step Walking speed slopeup                               -0.213909
# Regular step Walking speed gravel                                -0.009844
# Regular step Walking speed sidewalk                               0.582459
# Acceleration WithAverageZSlopeup                                 -0.207718
# Acceleration WithAverageZSlopedown                               -0.213307
# Acceleration WithAverageZGravel                                  -0.043242
# Acceleration WithAverageZSidewalk                                 0.300058
# Regular step WithoutStrideSlopeup                                -0.013932
# Regular step WithoutSpeedSlopeup                                  0.141225
# Regular step WithoutStrideSlopedown                               0.255525
# Regular step WithoutSpeedSlopedown                               -0.091568
# Regular step WithoutStrideGravel                                  0.965415
# Regular step WithoutSpeedGravel                                  -0.558051
# Regular step WithoutStrideSidewalk                                0.195517
# Regular step WithoutSpeedSidewalk                                 0.020286
# Regular step Withoutwspeed slopup                                -0.057872
# Regular step withoutspeedslopedown                                0.278728
# Regular step withoutwalkspeedgravel                               1.000000
# Regular step Withoutwalkspeedsidewalk                             0.190744
# Acceleration WithoutAverageZSlopeup                              -0.265057
# Acceleration WithoutAverageZSlopedown                            -0.188488
# Acceleration WithoutAverageZGravel                               -0.253909
# Acceleration WithoutAverageZSidewalk                             -0.092340
#
#                                        Regular step Withoutwalkspeedsidewalk  \
# Regular step WithStrideSlopeup                                     -0.353128
# Regular step WithSpeedSlopeup                                       0.029093
# Regular step WithStrideSlopedown                                    0.208806
# Regular step WithSpeedSlopdown                                     -0.098149
# Regular step WithStrideGravel                                       0.004404
# Regular step WithSpeedGravel                                        0.203955
# Regular step WithStrideSidwalk                                      0.223330
# Regular step WithSpeedSidewalk                                     -0.059570
# Regular step Walking speedslopdown                                  0.258713
# Regular step Walking speed slopeup                                 -0.299120
# Regular step Walking speed gravel                                  -0.103682
# Regular step Walking speed sidewalk                                 0.189457
# Acceleration WithAverageZSlopeup                                   -0.075654
# Acceleration WithAverageZSlopedown                                  0.146044
# Acceleration WithAverageZGravel                                    -0.232298
# Acceleration WithAverageZSidewalk                                   0.178029
# Regular step WithoutStrideSlopeup                                   0.324995
# Regular step WithoutSpeedSlopeup                                    0.309413
# Regular step WithoutStrideSlopedown                                 0.185388
# Regular step WithoutSpeedSlopedown                                  0.107891
# Regular step WithoutStrideGravel                                    0.206226
# Regular step WithoutSpeedGravel                                    -0.103925
# Regular step WithoutStrideSidewalk                                  0.940059
# Regular step WithoutSpeedSidewalk                                  -0.138679
# Regular step Withoutwspeed slopup                                   0.180249
# Regular step withoutspeedslopedown                                  0.152595
# Regular step withoutwalkspeedgravel                                 0.190744
# Regular step Withoutwalkspeedsidewalk                               1.000000
# Acceleration WithoutAverageZSlopeup                                -0.325488
# Acceleration WithoutAverageZSlopedown                               0.065495
# Acceleration WithoutAverageZGravel                                 -0.279282
# Acceleration WithoutAverageZSidewalk                                0.329935
#
#                                        Acceleration WithoutAverageZSlopeup  \
# Regular step WithStrideSlopeup                                    0.283768
# Regular step WithSpeedSlopeup                                    -0.027455
# Regular step WithStrideSlopedown                                 -0.388350
# Regular step WithSpeedSlopdown                                   -0.105132
# Regular step WithStrideGravel                                     0.225396
# Regular step WithSpeedGravel                                      0.258195
# Regular step WithStrideSidwalk                                    0.075884
# Regular step WithSpeedSidewalk                                   -0.013563
# Regular step Walking speedslopdown                               -0.373100
# Regular step Walking speed slopeup                                0.252621
# Regular step Walking speed gravel                                 0.073872
# Regular step Walking speed sidewalk                               0.062159
# Acceleration WithAverageZSlopeup                                 -0.020331
# Acceleration WithAverageZSlopedown                               -0.039467
# Acceleration WithAverageZGravel                                  -0.071728
# Acceleration WithAverageZSidewalk                                 0.007602
# Regular step WithoutStrideSlopeup                                -0.164114
# Regular step WithoutSpeedSlopeup                                 -0.441111
# Regular step WithoutStrideSlopedown                              -0.146505
# Regular step WithoutSpeedSlopedown                               -0.379818
# Regular step WithoutStrideGravel                                 -0.259201
# Regular step WithoutSpeedGravel                                   0.122157
# Regular step WithoutStrideSidewalk                               -0.259559
# Regular step WithoutSpeedSidewalk                                 0.199920
# Regular step Withoutwspeed slopup                                 0.006761
# Regular step withoutspeedslopedown                               -0.067368
# Regular step withoutwalkspeedgravel                              -0.265057
# Regular step Withoutwalkspeedsidewalk                            -0.325488
# Acceleration WithoutAverageZSlopeup                               1.000000
# Acceleration WithoutAverageZSlopedown                             0.007894
# Acceleration WithoutAverageZGravel                                0.039801
# Acceleration WithoutAverageZSidewalk                             -0.111099
#
#                                        Acceleration WithoutAverageZSlopedown  \
# Regular step WithStrideSlopeup                                      0.170705
# Regular step WithSpeedSlopeup                                      -0.022071
# Regular step WithStrideSlopedown                                    0.476998
# Regular step WithSpeedSlopdown                                      0.095025
# Regular step WithStrideGravel                                      -0.194136
# Regular step WithSpeedGravel                                        0.173731
# Regular step WithStrideSidwalk                                     -0.248471
# Regular step WithSpeedSidewalk                                      0.044598
# Regular step Walking speedslopdown                                  0.488411
# Regular step Walking speed slopeup                                  0.161109
# Regular step Walking speed gravel                                  -0.291392
# Regular step Walking speed sidewalk                                -0.243466
# Acceleration WithAverageZSlopeup                                    0.345880
# Acceleration WithAverageZSlopedown                                  0.044011
# Acceleration WithAverageZGravel                                     0.236006
# Acceleration WithAverageZSidewalk                                  -0.399514
# Regular step WithoutStrideSlopeup                                   0.004518
# Regular step WithoutSpeedSlopeup                                   -0.157368
# Regular step WithoutStrideSlopedown                                -0.411534
# Regular step WithoutSpeedSlopedown                                  0.103541
# Regular step WithoutStrideGravel                                   -0.187462
# Regular step WithoutSpeedGravel                                     0.132164
# Regular step WithoutStrideSidewalk                                  0.049167
# Regular step WithoutSpeedSidewalk                                  -0.049766
# Regular step Withoutwspeed slopup                                   0.056222
# Regular step withoutspeedslopedown                                 -0.443944
# Regular step withoutwalkspeedgravel                                -0.188488
# Regular step Withoutwalkspeedsidewalk                               0.065495
# Acceleration WithoutAverageZSlopeup                                 0.007894
# Acceleration WithoutAverageZSlopedown                               1.000000
# Acceleration WithoutAverageZGravel                                  0.027387
# Acceleration WithoutAverageZSidewalk                               -0.081485
#
#                                        Acceleration WithoutAverageZGravel  \
# Regular step WithStrideSlopeup                                   0.127201
# Regular step WithSpeedSlopeup                                   -0.065421
# Regular step WithStrideSlopedown                                -0.568440
# Regular step WithSpeedSlopdown                                  -0.252382
# Regular step WithStrideGravel                                    0.074736
# Regular step WithSpeedGravel                                    -0.110172
# Regular step WithStrideSidwalk                                  -0.371073
# Regular step WithSpeedSidewalk                                   0.475885
# Regular step Walking speedslopdown                              -0.551333
# Regular step Walking speed slopeup                               0.112823
# Regular step Walking speed gravel                                0.135459
# Regular step Walking speed sidewalk                             -0.404561
# Acceleration WithAverageZSlopeup                                 0.024791
# Acceleration WithAverageZSlopedown                               0.268881
# Acceleration WithAverageZGravel                                  0.361522
# Acceleration WithAverageZSidewalk                               -0.333619
# Regular step WithoutStrideSlopeup                               -0.268769
# Regular step WithoutSpeedSlopeup                                 0.048139
# Regular step WithoutStrideSlopedown                             -0.047515
# Regular step WithoutSpeedSlopedown                              -0.051037
# Regular step WithoutStrideGravel                                -0.379943
# Regular step WithoutSpeedGravel                                 -0.132042
# Regular step WithoutStrideSidewalk                              -0.289597
# Regular step WithoutSpeedSidewalk                               -0.021309
# Regular step Withoutwspeed slopup                               -0.248289
# Regular step withoutspeedslopedown                              -0.041194
# Regular step withoutwalkspeedgravel                             -0.253909
# Regular step Withoutwalkspeedsidewalk                           -0.279282
# Acceleration WithoutAverageZSlopeup                              0.039801
# Acceleration WithoutAverageZSlopedown                            0.027387
# Acceleration WithoutAverageZGravel                               1.000000
# Acceleration WithoutAverageZSidewalk                            -0.329976
#
#                                        Acceleration WithoutAverageZSidewalk
# Regular step WithStrideSlopeup                                    -0.111769
# Regular step WithSpeedSlopeup                                      0.005034
# Regular step WithStrideSlopedown                                   0.227115
# Regular step WithSpeedSlopdown                                    -0.047799
# Regular step WithStrideGravel                                      0.068248
# Regular step WithSpeedGravel                                       0.140305
# Regular step WithStrideSidwalk                                     0.249092
# Regular step WithSpeedSidewalk                                    -0.127884
# Regular step Walking speedslopdown                                 0.260450
# Regular step Walking speed slopeup                                -0.102383
# Regular step Walking speed gravel                                 -0.005460
# Regular step Walking speed sidewalk                                0.224861
# Acceleration WithAverageZSlopeup                                  -0.078049
# Acceleration WithAverageZSlopedown                                 0.065949
# Acceleration WithAverageZGravel                                   -0.109726
# Acceleration WithAverageZSidewalk                                  0.264825
# Regular step WithoutStrideSlopeup                                  0.198384
# Regular step WithoutSpeedSlopeup                                   0.119240
# Regular step WithoutStrideSlopedown                                0.105224
# Regular step WithoutSpeedSlopedown                                 0.027122
# Regular step WithoutStrideGravel                                  -0.056709
# Regular step WithoutSpeedGravel                                    0.145455
# Regular step WithoutStrideSidewalk                                 0.211637
# Regular step WithoutSpeedSidewalk                                 -0.334728
# Regular step Withoutwspeed slopup                                  0.133796
# Regular step withoutspeedslopedown                                 0.099748
# Regular step withoutwalkspeedgravel                               -0.092340
# Regular step Withoutwalkspeedsidewalk                              0.329935
# Acceleration WithoutAverageZSlopeup                               -0.111099
# Acceleration WithoutAverageZSlopedown                             -0.081485
# Acceleration WithoutAverageZGravel                                -0.329976
# Acceleration WithoutAverageZSidewalk                               1.000000
#
# [32 rows x 32 columns]

# %%
import pandas as pd
import numpy as np

# Load the dataset
df_rollator = pd.read_csv("/content/drive/MyDrive/new gait data/final_rollator_exampledata.csv")

# Custom formatting function
def print_header(text):
    print(f"\n{'='*60}")
    print(f"|| {text.upper()}")
    print(f"{'='*60}\n")

# 1. Dataset Overview
print_header("dataset overview")
print(f"• Total Records: {df_rollator.shape[0]}")
print(f"• Total Features: {df_rollator.shape[1]}")
print("\nFirst 3 rows:")
print(df_rollator.head(3).to_string())
print("\nData Types Distribution:")
print(df_rollator.dtypes.value_counts().to_string())

# 2. Missing Value Analysis
print_header("missing value analysis")
missing_df = df_rollator.isnull().sum().to_frame(name='Missing Count')
missing_df['Missing %'] = (missing_df['Missing Count'] / len(df_rollator)) * 100
print(missing_df.sort_values(by='Missing Count', ascending=False).to_string())

# 3. Cardinality Check
print_header("cardinality analysis")
unique_counts = df_rollator.nunique().to_frame(name='Unique Values')
unique_counts['Data Type'] = df_rollator.dtypes
print(unique_counts.sort_values(by='Unique Values', ascending=False).to_string())



# 5. Statistical Analysis
print_header("statistical summary")
numerical_cols = df_rollator.select_dtypes(include=np.number).columns
print("Numerical Features:")
print(df_rollator[numerical_cols].describe().transpose().to_string())

categorical_cols = df_rollator.select_dtypes(exclude=np.number).columns
print("\nCategorical Features:")
print(df_rollator[categorical_cols].describe().transpose().to_string())

# 6. Correlation Insights
print_header("correlation insights")
corr_matrix = df_rollator[numerical_cols].corr().abs()
strong_corrs = corr_matrix.unstack().sort_values(ascending=False).drop_duplicates()
strong_corrs = strong_corrs[strong_corrs > 0.7].dropna()
print("Strong Correlations (|r| > 0.7):")
print(strong_corrs.to_string())

# 7. Data Quality Flags
print_header("data quality flags")
print("• High Missing Values (>30%):")
print(missing_df[missing_df['Missing %'] > 30].to_string())
print("\n• High Cardinality Features (>50 unique values):")
print(unique_counts[unique_counts['Unique Values'] > 50].to_string())
print("\n• Potential Constant Features (<2 unique values):")
print(unique_counts[unique_counts['Unique Values'] < 2].to_string())

# 8. Suggested Actions
print_header("suggested next steps")
print("1. Time Column Standardization Needed")
print("2. Address High Missing Values in Acceleration WithAverageZSlopedown (66.67%)")
print("3. Investigate Strong Correlations Between:")
print("   - Regular step WithStrideSlopedown and Regular step Walking speedslopdown (r = 0.98)")
print("   - Regular step WithoutStrideSlopedown and Regular step withoutspeedslopedown (r = 0.98)")
print("4. Consider Feature Engineering for Temporal Measurements")
print("5. Evaluate High Cardinality Features for Dimensionality Reduction")
# Out:
# ============================================================
# || DATASET OVERVIEW
# ============================================================
#
# • Total Records: 60
# • Total Features: 48
#
# First 3 rows:
#   Regular step WithSlopeup  Regular step WithStrideSlopeup  Regular step WithSpeedSlopeup Regular step WithSlopedown  Regular step WithStrideSlopedown  Regular step WithSpeedSlopdown Regular step WithGravel  Regular step WithStrideGravel  Regular step WithSpeedGravel Regular step WithSidewalk  Regular step WithStrideSidwalk  Regular step WithSpeedSidewalk  Regular step Walking speedslopdown  Regular step Walking speed slopeup  Regular step Walking speed gravel  Regular step Walking speed sidewalk Acceleration WithSlopeup.1  Acceleration WithAverageZSlopeup Acceleration WithSlopedown.1  Acceleration WithAverageZSlopedown Acceleration WithGravel.1  Acceleration WithAverageZGravel Acceleration WithSidewalk.1  Acceleration WithAverageZSidewalk Regular step WithoutSlopeup  Regular step WithoutStrideSlopeup  Regular step WithoutSpeedSlopeup Regular step WithoutSlopedown  Regular step WithoutStrideSlopedown  Regular step WithoutSpeedSlopedown Regular step WithoutGravel  Regular step WithoutStrideGravel  Regular step WithoutSpeedGravel Regular step WithoutSidewalk  Regular step WithoutStrideSidewalk  Regular step WithoutSpeedSidewalk  Regular step Withoutwspeed slopup  Regular step withoutspeedslopedown  Regular step withoutwalkspeedgravel  Regular step Withoutwalkspeedsidewalk Acceleration WithoutSlopeup.1  Acceleration WithoutAverageZSlopeup Acceleration WithoutSlopedown.1  Acceleration WithoutAverageZSlopedown Acceleration WithoutGravel.1  Acceleration WithoutAverageZGravel Acceleration WithoutSidewalk.1  Acceleration WithoutAverageZSidewalk
# 0                  15:03.4                            61.0                          137.0                    31:51.5                              50.0                           118.0                 04:47.7                           49.0                         116.0                   10:42.4                            46.0                           114.0                            0.847458                            0.890511                           0.844828                             0.807018                    15:03.4                          0.203785                      31:51.5                            0.202874                   04:47.7                         0.206363                     10:42.4                           0.244541                    14:40:06                               47.0                             106.0                      14:54:12                                 52.0                               108.0                   14:30:12                              47.0                            118.0                     14:45:59                                45.0                              106.0                           0.886792                            0.962963                             0.796610                               0.849057                      14:40:07                             0.205800                        05:04:52                               0.205800                     14:30:13                            0.171123                        46:00.0                              0.220588
# 1                  15:04.6                            59.0                          122.0                    31:52.8                              47.0                           127.0                 04:48.9                           52.0                         118.0                   10:43.5                            48.0                           110.0                            0.740157                            0.967213                           0.881356                             0.872727                    15:04.6                          0.196560                      31:52.8                            0.203284                   04:48.9                         0.219780                     10:43.5                           0.252936                    14:40:07                               43.0                             106.0                      14:54:13                                 50.0                               106.0                   14:30:13                              57.0                             93.0                     14:46:00                                43.0                              108.0                           0.811321                            0.943396                             1.225806                               0.796296                      14:40:08                             0.202206                        05:05:07                               0.213333                     14:30:14                            0.209524                        46:01.1                              0.202392
# 2                  15:05.9                            63.0                          122.0                    31:54.0                              42.0                           122.0                 04:50.1                           51.0                         118.0                   10:44.7                            48.0                           116.0                            0.688525                            1.032787                           0.864407                             0.827586                    15:05.9                          0.212940                      31:54.0                            0.229320                   04:50.1                         0.202874                     10:44.7                           0.240757                    14:40:08                               41.0                             108.0                      14:54:14                                 54.0                               108.0                   14:30:14                              56.0                            105.0                     14:46:01                                46.0                              108.0                           0.759259                            1.000000                             1.066667                               0.851852                      14:40:09                             0.202392                        05:05:03                               0.205800                     14:30:15                            0.194175                        46:02.1                              0.220588
#
# Data Types Distribution:
# float64    32
# object     16
#
# ============================================================
# || MISSING VALUE ANALYSIS
# ============================================================
#
#                                        Missing Count  Missing %
# Regular step WithSlopedown                        41  68.333333
# Regular step WithStrideSlopedown                  41  68.333333
# Regular step WithSpeedSlopdown                    41  68.333333
# Acceleration WithSlopedown.1                      41  68.333333
# Acceleration WithAverageZSlopedown                40  66.666667
# Regular step Walking speedslopdown                39  65.000000
# Acceleration WithoutGravel.1                      28  46.666667
# Acceleration WithoutAverageZGravel                28  46.666667
# Regular step WithoutSpeedGravel                   27  45.000000
# Regular step WithoutGravel                        27  45.000000
# Regular step WithoutStrideGravel                  27  45.000000
# Regular step withoutwalkspeedgravel               25  41.666667
# Acceleration WithoutSlopedown.1                   25  41.666667
# Acceleration WithoutAverageZSlopedown             25  41.666667
# Regular step WithStrideSidwalk                    24  40.000000
# Regular step WithSpeedSidewalk                    24  40.000000
# Acceleration WithSidewalk.1                       24  40.000000
# Regular step WithSidewalk                         24  40.000000
# Acceleration WithAverageZSidewalk                 24  40.000000
# Regular step WithoutStrideSlopedown               23  38.333333
# Regular step WithoutSpeedSlopedown                23  38.333333
# Regular step WithoutSlopedown                     23  38.333333
# Acceleration WithAverageZSlopeup                  22  36.666667
# Regular step Walking speed sidewalk               22  36.666667
# Regular step WithSlopeup                          22  36.666667
# Regular step WithStrideSlopeup                    22  36.666667
# Regular step WithSpeedSlopeup                     22  36.666667
# Acceleration WithSlopeup.1                        22  36.666667
# Regular step withoutspeedslopedown                21  35.000000
# Regular step Walking speed slopeup                20  33.333333
# Acceleration WithoutSidewalk.1                    17  28.333333
# Regular step WithoutSpeedSidewalk                 17  28.333333
# Regular step WithoutStrideSidewalk                17  28.333333
# Acceleration WithoutAverageZSidewalk              17  28.333333
# Regular step WithoutSidewalk                      17  28.333333
# Regular step WithoutSlopeup                       16  26.666667
# Acceleration WithoutSlopeup.1                     16  26.666667
# Regular step Withoutwspeed slopup                 16  26.666667
# Regular step WithoutStrideSlopeup                 16  26.666667
# Regular step WithoutSpeedSlopeup                  16  26.666667
# Regular step Withoutwalkspeedsidewalk             15  25.000000
# Acceleration WithoutAverageZSlopeup               15  25.000000
# Regular step WithGravel                            2   3.333333
# Regular step WithStrideGravel                      2   3.333333
# Acceleration WithAverageZGravel                    2   3.333333
# Regular step WithSpeedGravel                       2   3.333333
# Acceleration WithGravel.1                          2   3.333333
# Regular step Walking speed gravel                  0   0.000000
#
# ============================================================
# || CARDINALITY ANALYSIS
# ============================================================
#
#                                        Unique Values Data Type
# Regular step WithGravel                           58    object
# Acceleration WithGravel.1                         58    object
# Regular step WithoutSlopeup                       44    object
# Acceleration WithoutSlopeup.1                     44    object
# Regular step WithoutSidewalk                      43    object
# Acceleration WithoutSidewalk.1                    43    object
# Acceleration WithSlopeup.1                        38    object
# Regular step WithSlopeup                          38    object
# Regular step WithoutSlopedown                     37    object
# Acceleration WithSidewalk.1                       36    object
# Regular step WithSidewalk                         36    object
# Regular step Walking speed slopeup                34   float64
# Regular step WithoutGravel                        33    object
# Acceleration WithoutSlopedown.1                   33    object
# Acceleration WithoutGravel.1                      32    object
# Regular step Walking speed sidewalk               31   float64
# Regular step Walking speed gravel                 30   float64
# Regular step withoutspeedslopedown                30   float64
# Regular step withoutwalkspeedgravel               29   float64
# Regular step Withoutwalkspeedsidewalk             26   float64
# Regular step Withoutwspeed slopup                 25   float64
# Acceleration WithoutAverageZSlopedown             22   float64
# Acceleration WithAverageZSlopeup                  21   float64
# Acceleration WithAverageZGravel                   19   float64
# Regular step Walking speedslopdown                19   float64
# Regular step WithSlopedown                        19    object
# Acceleration WithAverageZSidewalk                 19   float64
# Acceleration WithSlopedown.1                      19    object
# Acceleration WithoutAverageZGravel                18   float64
# Acceleration WithoutAverageZSlopeup               18   float64
# Regular step WithStrideSlopeup                    18   float64
# Regular step WithoutStrideSlopedown               17   float64
# Regular step WithStrideSidwalk                    15   float64
# Regular step WithoutStrideGravel                  15   float64
# Acceleration WithAverageZSlopedown                13   float64
# Acceleration WithoutAverageZSidewalk              12   float64
# Regular step WithStrideSlopedown                  12   float64
# Regular step WithStrideGravel                     10   float64
# Regular step WithoutSpeedGravel                   10   float64
# Regular step WithSpeedSidewalk                    10   float64
# Regular step WithoutStrideSidewalk                 9   float64
# Regular step WithoutStrideSlopeup                  9   float64
# Regular step WithSpeedSlopeup                      9   float64
# Regular step WithSpeedSlopdown                     8   float64
# Regular step WithSpeedGravel                       7   float64
# Regular step WithoutSpeedSlopeup                   7   float64
# Regular step WithoutSpeedSlopedown                 7   float64
# Regular step WithoutSpeedSidewalk                  4   float64
#
# ============================================================
# || STATISTICAL SUMMARY
# ============================================================
#
# Numerical Features:
#                                        count        mean       std         min         25%         50%         75%         max
# Regular step WithStrideSlopeup          38.0   62.842105  5.299293   52.000000   59.250000   62.000000   67.000000   74.000000
# Regular step WithSpeedSlopeup           38.0  119.578947  5.875426  104.000000  116.000000  118.000000  122.000000  137.000000
# Regular step WithStrideSlopedown        19.0   38.421053  7.081398   31.000000   33.000000   35.000000   43.000000   52.000000
# Regular step WithSpeedSlopdown          19.0  114.157895  4.645944  108.000000  110.000000  114.000000  116.000000  127.000000
# Regular step WithStrideGravel           58.0   51.155172  2.100975   47.000000   50.000000   51.000000   52.000000   60.000000
# Regular step WithSpeedGravel            58.0  117.206897  2.511438  112.000000  116.000000  116.000000  119.500000  124.000000
# Regular step WithStrideSidwalk          36.0   44.805556  7.505501   12.000000   45.000000   47.000000   48.000000   52.000000
# Regular step WithSpeedSidewalk          36.0  113.805556  6.898528  101.000000  110.000000  112.000000  116.000000  141.000000
# Regular step Walking speedslopdown      21.0    0.671657  0.104697    0.534483    0.592593    0.636364    0.719298    0.896552
# Regular step Walking speed slopeup      40.0    1.053247  0.099804    0.890511    0.983190    1.042134    1.123851    1.365385
# Regular step Walking speed gravel       60.0    0.873059  0.033942    0.813559    0.846800    0.875126    0.896552    0.983607
# Regular step Walking speed sidewalk     38.0    0.793338  0.138206    0.170213    0.790381    0.827586    0.856494    0.944444
# Acceleration WithAverageZSlopeup        38.0    0.229266  0.012111    0.196560    0.223368    0.232921    0.236686    0.253593
# Acceleration WithAverageZSlopedown      20.0    0.229751  0.010795    0.202874    0.227074    0.230906    0.235081    0.244755
# Acceleration WithAverageZGravel         58.0    0.215334  0.010551    0.189003    0.206186    0.216306    0.223368    0.236686
# Acceleration WithAverageZSidewalk       36.0    0.233700  0.028411    0.113314    0.234869    0.242649    0.248668    0.266430
# Regular step WithoutStrideSlopeup       44.0   41.772727  1.903041   38.000000   40.750000   41.500000   43.000000   47.000000
# Regular step WithoutSpeedSlopeup        44.0  105.500000  1.758699  102.000000  104.000000  106.000000  106.000000  110.000000
# Regular step WithoutStrideSlopedown     37.0   46.675676  5.840729   38.000000   42.000000   44.000000   51.000000   58.000000
# Regular step WithoutSpeedSlopedown      37.0  107.486486  2.445195  104.000000  106.000000  108.000000  108.000000  114.000000
# Regular step WithoutStrideGravel        33.0   48.575758  6.093184   28.000000   47.000000   50.000000   52.000000   57.000000
# Regular step WithoutSpeedGravel         33.0  106.606061  3.749495   93.000000  106.000000  106.000000  108.000000  118.000000
# Regular step WithoutStrideSidewalk      43.0   44.162791  2.057856   40.000000   43.000000   44.000000   46.000000   48.000000
# Regular step WithoutSpeedSidewalk       43.0  108.697674  1.739388  106.000000  108.000000  108.000000  110.000000  112.000000
# Regular step Withoutwspeed slopup       44.0    0.792720  0.041864    0.703704    0.766738    0.781818    0.826923    0.886792
# Regular step withoutspeedslopedown      39.0    0.868515  0.104413    0.730769    0.787136    0.846154    0.943396    1.094340
# Regular step withoutwalkspeedgravel     35.0    0.913711  0.125944    0.528302    0.870370    0.924528    0.981307    1.225806
# Regular step Withoutwalkspeedsidewalk   45.0    0.812660  0.036631    0.740741    0.781818    0.812580    0.833333    0.888889
# Acceleration WithoutAverageZSlopeup     45.0    0.209867  0.010840    0.187091    0.205800    0.209524    0.213592    0.243218
# Acceleration WithoutAverageZSlopedown   35.0    0.211709  0.013152    0.183824    0.204096    0.209724    0.220588    0.239190
# Acceleration WithoutAverageZGravel      32.0    0.199245  0.017010    0.171123    0.187266    0.202206    0.205993    0.262172
# Acceleration WithoutAverageZSidewalk    43.0    0.210205  0.008260    0.195382    0.202299    0.213144    0.216998    0.220791
#
# Categorical Features:
#                                 count unique       top freq
# Regular step WithSlopeup           38     38   15:03.4    1
# Regular step WithSlopedown         19     19   31:51.5    1
# Regular step WithGravel            58     58   04:47.7    1
# Regular step WithSidewalk          36     36   10:42.4    1
# Acceleration WithSlopeup.1         38     38   15:03.4    1
# Acceleration WithSlopedown.1       19     19   31:51.5    1
# Acceleration WithGravel.1          58     58   04:47.7    1
# Acceleration WithSidewalk.1        36     36   10:42.4    1
# Regular step WithoutSlopeup        44     44  14:40:06    1
# Regular step WithoutSlopedown      37     37  14:54:12    1
# Regular step WithoutGravel         33     33  14:30:12    1
# Regular step WithoutSidewalk       43     43  14:45:59    1
# Acceleration WithoutSlopeup.1      44     44  14:40:07    1
# Acceleration WithoutSlopedown.1    35     33  05:12:14    2
# Acceleration WithoutGravel.1       32     32  14:30:13    1
# Acceleration WithoutSidewalk.1     43     43   46:00.0    1
#
# ============================================================
# || CORRELATION INSIGHTS
# ============================================================
#
# Strong Correlations (|r| > 0.7):
# Regular step WithStrideSlopeup       Regular step WithStrideSlopeup           1.000000
# Regular step withoutspeedslopedown   Regular step WithoutStrideSlopedown      0.981657
# Regular step Walking speed sidewalk  Regular step WithStrideSidwalk           0.979702
# Regular step Walking speedslopdown   Regular step WithStrideSlopedown         0.977422
# Regular step withoutwalkspeedgravel  Regular step WithoutStrideGravel         0.965415
# Regular step Withoutwspeed slopup    Regular step WithoutStrideSlopeup        0.950119
# Regular step WithoutStrideSidewalk   Regular step Withoutwalkspeedsidewalk    0.940059
# Regular step Walking speed slopeup   Regular step WithStrideSlopeup           0.858506
# Regular step Walking speed gravel    Regular step WithStrideGravel            0.857251
# Regular step Walking speed sidewalk  Acceleration WithAverageZSidewalk        0.735999
# Acceleration WithAverageZSlopeup     Acceleration WithAverageZSlopedown       0.732738
# Regular step Walking speed sidewalk  Regular step WithSpeedSidewalk           0.728066
# Regular step WithStrideSidwalk       Acceleration WithAverageZSidewalk        0.722133
#
# ============================================================
# || DATA QUALITY FLAGS
# ============================================================
#
# • High Missing Values (>30%):
#                                        Missing Count  Missing %
# Regular step WithSlopeup                          22  36.666667
# Regular step WithStrideSlopeup                    22  36.666667
# Regular step WithSpeedSlopeup                     22  36.666667
# Regular step WithSlopedown                        41  68.333333
# Regular step WithStrideSlopedown                  41  68.333333
# Regular step WithSpeedSlopdown                    41  68.333333
# Regular step WithSidewalk                         24  40.000000
# Regular step WithStrideSidwalk                    24  40.000000
# Regular step WithSpeedSidewalk                    24  40.000000
# Regular step Walking speedslopdown                39  65.000000
# Regular step Walking speed slopeup                20  33.333333
# Regular step Walking speed sidewalk               22  36.666667
# Acceleration WithSlopeup.1                        22  36.666667
# Acceleration WithAverageZSlopeup                  22  36.666667
# Acceleration WithSlopedown.1                      41  68.333333
# Acceleration WithAverageZSlopedown                40  66.666667
# Acceleration WithSidewalk.1                       24  40.000000
# Acceleration WithAverageZSidewalk                 24  40.000000
# Regular step WithoutSlopedown                     23  38.333333
# Regular step WithoutStrideSlopedown               23  38.333333
# Regular step WithoutSpeedSlopedown                23  38.333333
# Regular step WithoutGravel                        27  45.000000
# Regular step WithoutStrideGravel                  27  45.000000
# Regular step WithoutSpeedGravel                   27  45.000000
# Regular step withoutspeedslopedown                21  35.000000
# Regular step withoutwalkspeedgravel               25  41.666667
# Acceleration WithoutSlopedown.1                   25  41.666667
# Acceleration WithoutAverageZSlopedown             25  41.666667
# Acceleration WithoutGravel.1                      28  46.666667
# Acceleration WithoutAverageZGravel                28  46.666667
#
# • High Cardinality Features (>50 unique values):
#                            Unique Values Data Type
# Regular step WithGravel               58    object
# Acceleration WithGravel.1             58    object
#
# • Potential Constant Features (<2 unique values):
# Empty DataFrame
# Columns: [Unique Values, Data Type]
# Index: []
#
# ============================================================
# || SUGGESTED NEXT STEPS
# ============================================================
#
# 1. Time Column Standardization Needed
# 2. Address High Missing Values in Acceleration WithAverageZSlopedown (66.67%)
# 3. Investigate Strong Correlations Between:
#    - Regular step WithStrideSlopedown and Regular step Walking speedslopdown (r = 0.98)
#    - Regular step WithoutStrideSlopedown and Regular step withoutspeedslopedown (r = 0.98)
# 4. Consider Feature Engineering for Temporal Measurements
# 5. Evaluate High Cardinality Features for Dimensionality Reduction
